# %%
import pandas as pd
df = pd.read_csv('heatmap_coordinate_data.csv')  
df.head()
# Out:
#    Latitude  Longitude     Score
# 0   34.3209  -118.2247  0.029213
# 1   41.8401   -87.8168  0.031613
# 2   29.8577   -95.3936  0.041455
# 3   33.3490  -112.4915  0.045561
# 4   33.0343  -116.7350  0.029962

# %%
df['Score'].max()
# Out:
# 0.1942393287614034

# %%
df['Score'] = 1-df['Score']

# %%
df.head()
# Out:
#    Latitude  Longitude     Score
# 0   34.3209  -118.2247  0.970787
# 1   41.8401   -87.8168  0.968387
# 2   29.8577   -95.3936  0.958545
# 3   33.3490  -112.4915  0.954439
# 4   33.0343  -116.7350  0.970038

# %%
df.to_csv('filename.csv', index=False)

# %%
df = pd.read_csv('updated_with_state_icu_normalized.csv')
df.head()
# Out:
#    Rank                          Current/Most Recent Study     Status  \
# 0     1  Retrospective Postoperative ARDS Study at Vand...  Completed
# 1     2  The Relationship Between Positive End Expirato...  Completed
# 2     3  Associations Between COVID-19 ARDS Treatment, ...  Completed
# 3     4  Assessing the Role of Inclined Positioning in ...  Completed
# 4     5  Dornase Alfa for ARDS in Patients With Severe ...  Completed
#
#           Study Results                           Interventions  \
# 0  No Results Available                                     NaN
# 1  No Results Available                                     NaN
# 2  No Results Available      Other: ARDS and COVID19 treatments
# 3  No Results Available                  Procedure: upright bed
# 4           Has Results  Drug: Dornase Alfa Inhalation Solution
#
#                                     Outcome Measures  \
# 0                                               ARDS
# 1                                      Cardiac Index
# 2  Index Hospital Survival|Time to Mechanical Ven...
# 3  highest value per day of mechanical ventilatio...
# 4  Change in Arterial Blood Oxygen Content to Fra...
#
#                                                 Age          Phases  \
# 0  11 Years and older   (Child, Adult, Older Adult)             NaN
# 1         18 Years and older   (Adult, Older Adult)             NaN
# 2                         Child, Adult, Older Adult             NaN
# 3       18 Years to 80 Years   (Adult, Older Adult)  Not Applicable
# 4         18 Years and older   (Adult, Older Adult)         Phase 3
#
#    Enrollment      Study Type  ...  \
# 0        89.0   Observational  ...
# 1       367.0   Observational  ...
# 2      1800.0   Observational  ...
# 3         5.0  Interventional  ...
# 4        30.0  Interventional  ...
#
#                                        Hospital Name  \
# 0    Vanderbilt University Medical Center, Nashville
# 1                Yale University, School of Medicine
# 2  Feinstein Institutes for Medical Research, Man...
# 3                  University of Kentucky, Lexington
# 4  University of Missouri Hospital and Clinics, C...
#
#                               Temp Locations 2      Principal Investigator  \
# 0         Vanderbilt University Medical Center  Christopher G Hughes, M.D.
# 1                              Yale University      Wassim H Fares, MD MSc
# 2    Feinstein Institutes for Medical Research    Negin Hajizadeh, MD, MPH
# 3                       University of Kentucky                         NaN
# 4  University of Missouri Hospital and Clinics      Zachary M Holliday, MD
#
#                                       County  ICU Beds in the County  \
# 0                                   Davidson                   614.0
# 1  South Central Connecticut Planning Region                     NaN
# 2                                     Nassau                   461.0
# 3                                    Fayette                     3.0
# 4                                      Boone                     0.0
#
#    Composite Score  Total Successful Trials        State ICU Beds true  \
# 0         0.384689                        2    Tennessee         614.0
# 1              NaN                        1  Connecticut           NaN
# 2         0.313666                        1     New York         461.0
# 3         0.479679                        2     Kentucky         260.0
# 4         0.368951                        2     Missouri         110.0
#
#   Normalized Composite Scores
# 0                   69.009213
# 1                         NaN
# 2                   47.052557
# 3                   98.375277
# 4                   64.143626
#
# [5 rows x 27 columns]
